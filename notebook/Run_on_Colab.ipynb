# %% [markdown]
# # 🚀 Run NIFTY 50 Forecasting System in Google Colab
#
# This notebook allows you to clone the project repository, install dependencies, and run the training pipeline directly in the cloud (Google Colab).

# %% [markdown]
# ## 1. Clone the Repository

# %%
# !git clone https://github.com/rkpcode/NIFTY50_Forecasting_System.git
# %cd NIFTY50_Forecasting_System

# %% [markdown]
# ## 2. Install Dependencies

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 3. Run Training Pipeline
# This will fetch data, train the LSTM model, and save it to `artifacts/model.h5`.

# %%
# !python src/nifty50_forecasting_system/pipelines/training_pipeline.py

# %% [markdown]
# ## 4. Download Trained Model
# Download the trained model to your local machine.

# %%
from google.colab import files
import os

if os.path.exists('artifacts/model.h5'):
    files.download('artifacts/model.h5')
else:
    print("Model artifact not found. Please check if training was successful.")
